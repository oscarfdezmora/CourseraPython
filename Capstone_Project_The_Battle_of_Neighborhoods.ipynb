# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarfdezmora/CourseraPython/blob/master/Capstone_Project_The_Battle_of_Neighborhoods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# ---
#
#
#
# A firm of medical supplies wants to open a new pharmacy in Toronto, and is interested in looking for new opportunities Scarborough.
#
# Taking into account the density of this kind of commerces in the area, we will offer a set most likely boroughs to open their store.
#
# This kind of study would be suitable for profiling any kind of store or venue in a sets of address, by means of geospatial tools such as Foursquare or Google Maps.

# %% [markdown]
# # **Data Section**
#
# ---
#
#
#
# We will focus on thos nighborhoods which are address in **North York, Toronto**. This locations will be provided by the postal code information settled in Wikipedia (source: [List of postal codes of Canada: M](https://www.wikiwand.com/en/List_of_postal_codes_of_Canada:_M))
#
# **Geocoder** was used to determinate latitude and longitude co-ordinates
#
# The **Foursquare API** will be use to find locations and look for those area which lack of pharmacies in the nearbies.
#
# The data retrieved contains information of venues within a specified distance of the longitude and latitude of the postcodes. The information obtained per venue as follows:
#
# 1. Neighborhood
# 2. Neighborhood Latitude
# 3. Neighborhood Longitude
# 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category

# %% [markdown]
# # **Methodology - Data Preparation - Wikipedia**
#
#
# ---
#
#
# The **postal information** from Wikipedia was downloaded and transform into a pandas dataframe, which had three columns:
#
#
# *   Postal Code
#
# *   Borough
#
# *   Neighborhood
#
#
#
# Once done this, common extraction and data cleaning were done:
#
#
# *   Only the cells that have an assigned borough were processed; cells with a borough that is Not assigned were ignored.
#
# *   More than one neighborhood can exist in one postal code area.
#
# *   If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
#
#
# Using **Geocoder**, we retrieve the latitude and longitude for each neighboorhood, and add them as columns.
# Our data frame will have five columns.
#
# *   Postal Code
#
# *   Borough
#
# *   Neighborhood
#
# *   Latitude
#
# *   Longitude

# %%
## Libraries and environment setup

# !pip install geocoder
# !pip install folium

import pandas as pd
import requests
import numpy as np
import geocoder
import folium
import requests 
import matplotlib.cm as cm
import matplotlib.colors as colors
import json
import xml
import matplotlib.pyplot as plt
# %matplotlib inline

from pandas.io.json import json_normalize 
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim 
from bs4 import BeautifulSoup

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Requirement already satisfied: geocoder in /usr/local/lib/python3.6/dist-packages (1.38.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder) (1.12.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2020.4.5.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)

# %%
## Get Data from Wikipedia
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
df = df[df.Borough != 'Not assigned']
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
df = df.groupby(['Postal Code', 'Borough'])['Neighborhood'].apply(list).apply(lambda x:', '.join(x)).to_frame().reset_index()
df.head()
# Out:
#   Postal Code      Borough                            Neighborhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %%
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.
for index, row in df.iterrows():
    if row['Neighborhood'] == 'Not assigned':
        row['Neighborhood'] = row['Borough']

# %%
## Define function to retrieve Latitude & Longitude from Geocoder

def get_latilong(postal_code):
    coords = None
    while(coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        coords = g.latlng
    return coords

# %%
# Retrieving Postal Code Co-ordinates
postal_codes = df['Postal Code']    
coords = [ get_latilong(postal_code) for postal_code in postal_codes.tolist() ]

# Adding Columns Latitude & Longitude to our DataFrame
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df['Latitude'] = df_coords['Latitude']
df['Longitude'] = df_coords['Longitude']

df.head()
# Out:
#   Postal Code      Borough                            Neighborhood   Latitude  \
# 0         M1B  Scarborough                          Malvern, Rouge  43.808626
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.785779
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill  43.765806
# 3         M1G  Scarborough                                  Woburn  43.771545
# 4         M1H  Scarborough                               Cedarbrae  43.768791
#
#    Longitude
# 0 -79.189913
# 1 -79.157368
# 2 -79.185284
# 3 -79.218135
# 4 -79.238813

# %% [markdown]
# # Methodology - Data Preparation - Foursquare
#
# ---

# %%
##Credentials for Foursquare connection

CLIENT_ID = "UAH2DBVN5TBHSYUMSYKXPGEERYSEXBEKBE5XA2RDDAHYLXHX"
CLIENT_SECRET = "RWH0BUK1B5ZGIFJS0BNCTHESAIXLI0FHY0RXR40ME3RRBNSO"
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UAH2DBVN5TBHSYUMSYKXPGEERYSEXBEKBE5XA2RDDAHYLXHX
# CLIENT_SECRET:RWH0BUK1B5ZGIFJS0BNCTHESAIXLI0FHY0RXR40ME3RRBNSO

# %%
## Function that will get all the venues from a given location, in 700 m round

def getNearbyVenues(names, latitudes, longitudes, radius=700):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # making GET request
        venue_results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in venue_results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Get all the venues from the list of neighbourhoods
Scarborough_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# York Mills, Silver Hills
# Willowdale, Newtonbrook
# Willowdale, Willowdale East
# York Mills West
# Willowdale, Willowdale West
# Parkwoods
# Don Mills
# Don Mills
# Bathurst Manor, Wilson Heights, Downsview North
# Northwood Park, York University
# Downsview
# Downsview
# Downsview
# Downsview
# Victoria Village
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto, Broadview North (Old East York)
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West, Lawrence Park
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North & West, Forest Hill Road Park
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes
# First Canadian Place, Underground city
# Lawrence Manor, Lawrence Heights
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# North Park, Maple Leaf Park, Upwood Park
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Runnymede, The Junction North
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park, Ontario Provincial Government
# Canada Post Gateway Processing Centre
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# New Toronto, Mimico South, Humber Bay Shores
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# Islington Avenue, Humber Valley Village
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Humber Summit
# Humberlea, Emery
# Weston
# Westmount
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Northwest, West Humber - Clairville

# %%
## Get all the neighbours which have a pharmacy 
Scarborough_pharmacy = Scarborough_venues[Scarborough_venues["Venue Category"] == "Pharmacy"]
Scarborough_pharmacy.reset_index(drop = True, inplace = True)

Scarborough_pharmacy
# Out:
#                                          Neighborhood  Neighborhood Latitude  \
# 0                   Guildwood, Morningside, West Hill              43.765806
# 1         Kennedy Park, Ionview, East Birchmount Park              43.726881
# 2     Cliffside, Cliffcrest, Scarborough Village West              43.723538
# 3                                           Agincourt              43.793930
# 4             Clarks Corners, Tam O'Shanter, Sullivan              43.784902
# 5             Clarks Corners, Tam O'Shanter, Sullivan              43.784902
# 6             Clarks Corners, Tam O'Shanter, Sullivan              43.784902
# 7   Milliken, Agincourt North, Steeles East, L'Amo...              43.817998
# 8   Milliken, Agincourt North, Steeles East, L'Amo...              43.817998
# 9                       Steeles West, L'Amoreaux West              43.800530
# 10                                  Hillcrest Village              43.802556
# 11                       Fairview, Henry Farm, Oriole              43.780306
# 12                        Willowdale, Willowdale West              43.779912
# 13                                          Don Mills              43.748900
# 14    Bathurst Manor, Wilson Heights, Downsview North              43.757394
# 15                                          Downsview              43.755819
# 16                    Parkview Hill, Woodbine Gardens              43.707193
# 17                                   Woodbine Heights              43.689740
# 18                                   Thorncliffe Park              43.702072
# 19                                   Davisville North              43.713171
# 20                  Bedford Park, Lawrence Manor East              43.735447
# 21    Forest Hill North & West, Forest Hill Road Park              43.694460
# 22                   Lawrence Manor, Lawrence Heights              43.723265
# 23                      High Park, The Junction South              43.658720
# 24      The Kingsway, Montgomery Road, Old Mill North              43.653340
# 25            Islington Avenue, Humber Valley Village              43.667481
# 26            Islington Avenue, Humber Valley Village              43.667481
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.637813
# 28                                             Weston              43.705496
# 29  Kingsview Village, St. Phillips, Martin Grove ...              43.686887
# 30  South Steeles, Silverstone, Humbergate, Jamest...              43.744055
#
#     Neighborhood Longitude                               Venue  \
# 0               -79.185284                  Shoppers Drug Mart
# 1               -79.265694                  Shoppers Drug Mart
# 2               -79.228353                  Shoppers Drug Mart
# 3               -79.265694                  Shoppers Drug Mart
# 4               -79.304725                  Shoppers Drug Mart
# 5               -79.304725                              Rexall
# 6               -79.304725                              Rexall
# 7               -79.280887  Brimley Road Medical Center I.D.A.
# 8               -79.280887                        IDA Pharmacy
# 9               -79.321830                  Shoppers Drug Mart
# 10              -79.356566           Cliffwood I.D.A. Pharmacy
# 11              -79.348687                  Shoppers Drug Mart
# 12              -79.445229                  Shoppers Drug Mart
# 13              -79.357220                  Shoppers Drug Mart
# 14              -79.442394                  Shoppers Drug Mart
# 15              -79.519973                  Shoppers Drug Mart
# 16              -79.311529                  Shoppers Drug Mart
# 17              -79.308507                  Shoppers Drug Mart
# 18              -79.351614                  Shoppers Drug Mart
# 19              -79.388870                  Shoppers Drug Mart
# 20              -79.417944                  Shoppers Drug Mart
# 21              -79.410280                              Rexall
# 22              -79.451211                  Shoppers Drug Mart
# 23              -79.463150                       IDA High Park
# 24              -79.509766                  Shoppers Drug Mart
# 25              -79.528953                  Shoppers Drug Mart
# 26              -79.528953               Thorncrest Drug Store
# 27              -79.576484                  Shoppers Drug Mart
# 28              -79.520370                  Shoppers Drug Mart
# 29              -79.565507                  Shoppers Drug Mart
# 30              -79.581203                  Shoppers Drug Mart
#
#     Venue Latitude  Venue Longitude Venue Category
# 0        43.770282       -79.185012       Pharmacy
# 1        43.732843       -79.268075       Pharmacy
# 2        43.725669       -79.231626       Pharmacy
# 3        43.797533       -79.272498       Pharmacy
# 4        43.785077       -79.310585       Pharmacy
# 5        43.780900       -79.298764       Pharmacy
# 6        43.780732       -79.298257       Pharmacy
# 7        43.821167       -79.283655       Pharmacy
# 8        43.821293       -79.284015       Pharmacy
# 9        43.799966       -79.317985       Pharmacy
# 10       43.807909       -79.357777       Pharmacy
# 11       43.778170       -79.345014       Pharmacy
# 12       43.784847       -79.446028       Pharmacy
# 13       43.754171       -79.358057       Pharmacy
# 14       43.756239       -79.439599       Pharmacy
# 15       43.756147       -79.515843       Pharmacy
# 16       43.705933       -79.312825       Pharmacy
# 17       43.687934       -79.303381       Pharmacy
# 18       43.705810       -79.347044       Pharmacy
# 19       43.707806       -79.389893       Pharmacy
# 20       43.736276       -79.419705       Pharmacy
# 21       43.688526       -79.412392       Pharmacy
# 22       43.724775       -79.455380       Pharmacy
# 23       43.653316       -79.466811       Pharmacy
# 24       43.647623       -79.510860       Pharmacy
# 25       43.663067       -79.531753       Pharmacy
# 26       43.662988       -79.531817       Pharmacy
# 27       43.641312       -79.576924       Pharmacy
# 28       43.701264       -79.519705       Pharmacy
# 29       43.683881       -79.564842       Pharmacy
# 30       43.741685       -79.584487       Pharmacy

# %%
## We count the number of Pharmacies that are in each neighborhood

Scarborough_phar_coun = Scarborough_pharmacy['Neighborhood'].value_counts()

Scarborough_phar_coun = Scarborough_phar_coun.to_frame()
Scarborough_phar_coun.rename(columns={'Neighborhood':'Pharmacy'},inplace=True)
Scarborough_phar_coun
# Out:
#                                                     Pharmacy
# Clarks Corners, Tam O'Shanter, Sullivan                    3
# Milliken, Agincourt North, Steeles East, L'Amor...         2
# Islington Avenue, Humber Valley Village                    2
# Kennedy Park, Ionview, East Birchmount Park                1
# Fairview, Henry Farm, Oriole                               1
# High Park, The Junction South                              1
# Hillcrest Village                                          1
# Cliffside, Cliffcrest, Scarborough Village West            1
# Bedford Park, Lawrence Manor East                          1
# Guildwood, Morningside, West Hill                          1
# Don Mills                                                  1
# Weston                                                     1
# Thorncliffe Park                                           1
# Parkview Hill, Woodbine Gardens                            1
# South Steeles, Silverstone, Humbergate, Jamesto...         1
# Davisville North                                           1
# The Kingsway, Montgomery Road, Old Mill North              1
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...         1
# Lawrence Manor, Lawrence Heights                           1
# Kingsview Village, St. Phillips, Martin Grove G...         1
# Woodbine Heights                                           1
# Willowdale, Willowdale West                                1
# Forest Hill North & West, Forest Hill Road Park            1
# Downsview                                                  1
# Agincourt                                                  1
# Steeles West, L'Amoreaux West                              1
# Bathurst Manor, Wilson Heights, Downsview North            1

# %%
## We join the number of Pharmacies to each neighboorhood in our data set with the coordinates.

df_joined = df.set_index("Neighborhood").join(Scarborough_phar_coun,how='outer',lsuffix='main', rsuffix='phar')
df_final = df_joined.fillna(0)
df_final
# Out:
#                                                    Postal Code  \
# Agincourt                                                  M1S
# Alderwood, Long Branch                                     M8W
# Bathurst Manor, Wilson Heights, Downsview North            M3H
# Bayview Village                                            M2K
# Bedford Park, Lawrence Manor East                          M5M
# Berczy Park                                                M5E
# Birch Cliff, Cliffside West                                M1N
# Brockton, Parkdale Village, Exhibition Place               M6K
# Business reply mail Processing Centre, South Ce...         M7Y
# CN Tower, King and Spadina, Railway Lands, Harb...         M5V
# Caledonia-Fairbanks                                        M6E
# Canada Post Gateway Processing Centre                      M7R
# Cedarbrae                                                  M1H
# Central Bay Street                                         M5G
# Christie                                                   M6G
# Church and Wellesley                                       M4Y
# Clarks Corners, Tam O'Shanter, Sullivan                    M1T
# Cliffside, Cliffcrest, Scarborough Village West            M1M
# Commerce Court, Victoria Hotel                             M5L
# Davisville                                                 M4S
# Davisville North                                           M4P
# Del Ray, Mount Dennis, Keelsdale and Silverthorn           M6M
# Don Mills                                                  M3B
# Don Mills                                                  M3C
# Dorset Park, Wexford Heights, Scarborough Town ...         M1P
# Downsview                                                  M3K
# Downsview                                                  M3L
# Downsview                                                  M3M
# Downsview                                                  M3N
# Dufferin, Dovercourt Village                               M6H
# East Toronto, Broadview North (Old East York)              M4J
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...         M9C
# Fairview, Henry Farm, Oriole                               M2J
# First Canadian Place, Underground city                     M5X
# Forest Hill North & West, Forest Hill Road Park            M5P
# Garden District, Ryerson                                   M5B
# Glencairn                                                  M6B
# Golden Mile, Clairlea, Oakridge                            M1L
# Guildwood, Morningside, West Hill                          M1E
# Harbourfront East, Union Station, Toronto Islands          M5J
# High Park, The Junction South                              M6P
# Hillcrest Village                                          M2H
# Humber Summit                                              M9L
# Humberlea, Emery                                           M9M
# Humewood-Cedarvale                                         M6C
# India Bazaar, The Beaches West                             M4L
# Islington Avenue, Humber Valley Village                    M9A
# Kennedy Park, Ionview, East Birchmount Park                M1K
# Kensington Market, Chinatown, Grange Park                  M5T
# Kingsview Village, St. Phillips, Martin Grove G...         M9R
# Lawrence Manor, Lawrence Heights                           M6A
# Lawrence Park                                              M4N
# Leaside                                                    M4G
# Little Portugal, Trinity                                   M6J
# Malvern, Rouge                                             M1B
# Milliken, Agincourt North, Steeles East, L'Amor...         M1V
# Mimico NW, The Queensway West, South of Bloor, ...         M8Z
# Moore Park, Summerhill East                                M4T
# New Toronto, Mimico South, Humber Bay Shores               M8V
# North Park, Maple Leaf Park, Upwood Park                   M6L
# North Toronto West, Lawrence Park                          M4R
# Northwest, West Humber - Clairville                        M9W
# Northwood Park, York University                            M3J
# Old Mill South, King's Mill Park, Sunnylea, Hum...         M8Y
# Parkdale, Roncesvalles                                     M6R
# Parkview Hill, Woodbine Gardens                            M4B
# Parkwoods                                                  M3A
# Queen's Park, Ontario Provincial Government                M7A
# Regent Park, Harbourfront                                  M5A
# Richmond, Adelaide, King                                   M5H
# Rosedale                                                   M4W
# Roselawn                                                   M5N
# Rouge Hill, Port Union, Highland Creek                     M1C
# Runnymede, Swansea                                         M6S
# Runnymede, The Junction North                              M6N
# Scarborough Village                                        M1J
# South Steeles, Silverstone, Humbergate, Jamesto...         M9V
# St. James Town                                             M5C
# St. James Town, Cabbagetown                                M4X
# Steeles West, L'Amoreaux West                              M1W
# Stn A PO Boxes                                             M5W
# Studio District                                            M4M
# Summerhill West, Rathnelly, South Hill, Forest ...         M4V
# The Annex, North Midtown, Yorkville                        M5R
# The Beaches                                                M4E
# The Danforth West, Riverdale                               M4K
# The Kingsway, Montgomery Road, Old Mill North              M8X
# Thorncliffe Park                                           M4H
# Toronto Dominion Centre, Design Exchange                   M5K
# University of Toronto, Harbord                             M5S
# Upper Rouge                                                M1X
# Victoria Village                                           M4A
# West Deane Park, Princess Gardens, Martin Grove...         M9B
# Westmount                                                  M9P
# Weston                                                     M9N
# Wexford, Maryvale                                          M1R
# Willowdale, Newtonbrook                                    M2M
# Willowdale, Willowdale East                                M2N
# Willowdale, Willowdale West                                M2R
# Woburn                                                     M1G
# Woodbine Heights                                           M4C
# York Mills West                                            M2P
# York Mills, Silver Hills                                   M2L
#
#                                                              Borough  \
# Agincourt                                                Scarborough
# Alderwood, Long Branch                                     Etobicoke
# Bathurst Manor, Wilson Heights, Downsview North           North York
# Bayview Village                                           North York
# Bedford Park, Lawrence Manor East                         North York
# Berczy Park                                         Downtown Toronto
# Birch Cliff, Cliffside West                              Scarborough
# Brockton, Parkdale Village, Exhibition Place            West Toronto
# Business reply mail Processing Centre, South Ce...      East Toronto
# CN Tower, King and Spadina, Railway Lands, Harb...  Downtown Toronto
# Caledonia-Fairbanks                                             York
# Canada Post Gateway Processing Centre                    Mississauga
# Cedarbrae                                                Scarborough
# Central Bay Street                                  Downtown Toronto
# Christie                                            Downtown Toronto
# Church and Wellesley                                Downtown Toronto
# Clarks Corners, Tam O'Shanter, Sullivan                  Scarborough
# Cliffside, Cliffcrest, Scarborough Village West          Scarborough
# Commerce Court, Victoria Hotel                      Downtown Toronto
# Davisville                                           Central Toronto
# Davisville North                                     Central Toronto
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                York
# Don Mills                                                 North York
# Don Mills                                                 North York
# Dorset Park, Wexford Heights, Scarborough Town ...       Scarborough
# Downsview                                                 North York
# Downsview                                                 North York
# Downsview                                                 North York
# Downsview                                                 North York
# Dufferin, Dovercourt Village                            West Toronto
# East Toronto, Broadview North (Old East York)              East York
# Eringate, Bloordale Gardens, Old Burnhamthorpe,
# Don Mills                                                1.0
# Dorset Park, Wexford Heights, Scarborough Town ...       0.0
# Downsview                                                1.0
# Downsview                                                1.0
# Downsview                                                1.0
# Downsview                                                1.0
# Dufferin, Dovercourt Village                             0.0
# East Toronto, Broadview North (Old East York)            0.0
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...       1.0
# Fairview, Henry Farm, Oriole                             1.0
# First Canadian Place, Underground city                   0.0
# Forest Hill North & West, Forest Hill Road Park          1.0
# Garden District, Ryerson                                 0.0
# Glencairn                                                0.0
# Golden Mile, Clairlea, Oakridge                          0.0
# Guildwood, Morningside, West Hill                        1.0
# Harbourfront East, Union Station, Toronto Islands        0.0
# High Park, The Junction South                            1.0
# Hillcrest Village                                        1.0
# Humber Summit                                            0.0
# Humberlea, Emery                                         0.0
# Humewood-Cedarvale                                       0.0
# India Bazaar, The Beaches West                           0.0
# Islington Avenue, Humber Valley Village                  2.0
# Kennedy Park, Ionview, East Birchmount Park              1.0
# Kensington Market, Chinatown, Grange Park                0.0
# Kingsview Village, St. Phillips, Martin Grove G...       1.0
# Lawrence Manor, Lawrence Heights                         1.0
# Lawrence Park                                            0.0
# Leaside                                                  0.0
# Little Portugal, Trinity                                 0.0
# Malvern, Rouge                                           0.0
# Milliken, Agincourt North, Steeles East, L'Amor...       2.0
# Mimico NW, The Queensway West, South of Bloor, ...       0.0
# Moore Park, Summerhill East                              0.0
# New Toronto, Mimico South, Humber Bay Shores             0.0
# North Park, Maple Leaf Park, Upwood Park                 0.0
# North Toronto West, Lawrence Park                        0.0
# Northwest, West Humber - Clairville                      0.0
# Northwood Park, York University                          0.0
# Old Mill South, King's Mill Park, Sunnylea, Hum...       0.0
# Parkdale, Roncesvalles                                   0.0
# Parkview Hill, Woodbine Gardens                          1.0
# Parkwoods                                                0.0
# Queen's Park, Ontario Provincial Government              0.0
# Regent Park, Harbourfront                                0.0
# Richmond, Adelaide, King                                 0.0
# Rosedale                                                 0.0
# Roselawn                                                 0.0
# Rouge Hill, Port Union, Highland Creek                   0.0
# Runnymede, Swansea                                       0.0
# Runnymede, The Junction North                            0.0
# Scarborough Village                                      0.0
# South Steeles, Silverstone, Humbergate, Jamesto...       1.0
# St. James Town                                           0.0
# St. James Town, Cabbagetown                              0.0
# Steeles West, L'Amoreaux West                            1.0
# Stn A PO Boxes                                           0.0
# Studio District                                          0.0
# Summerhill West, Rathnelly, South Hill, Forest ...       0.0
# The Annex, North Midtown, Yorkville                      0.0
# The Beaches                                              0.0
# The Danforth West, Riverdale                             0.0
# The Kingsway, Montgomery Road, Old Mill North            1.0
# Thorncliffe Park                                         1.0
# Toronto Dominion Centre, Design Exchange                 0.0
# University of Toronto, Harbord                           0.0
# Upper Rouge                                              0.0
# Victoria Village                                         0.0
# West Deane Park, Princess Gardens, Martin Grove...       0.0
# Westmount                                                0.0
# Weston                                                   1.0
# Wexford, Maryvale                                        0.0
# Willowdale, Newtonbrook                                  0.0
# Willowdale, Willowdale East                              0.0
# Willowdale, Willowdale West                              1.0
# Woburn                                                   0.0
# Woodbine Heights                                         1.0
# York Mills West                                          0.0
# York Mills, Silver Hills                                 0.0

# %%
## A representation of Scarborough map, painting in green those neighborhoods without Pharmacies, yellow those with one, and red those with two or more

map_Scarborough = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, nei, far in zip(df_final['Latitude'], df_final['Longitude'], df_final.index, df_final['Pharmacy']):
    
    label = '{}'.format(nei)
    label = folium.Popup(label, parse_html=True)
    if far>1:
      change='red'
    elif far==1: 
      change="yellow"
    else: 
      change="green"

    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=change,
        fill=True,
        fill_color=change,
        fill_opacity=0.7,
        parse_html=False).add_to(map_Scarborough)  
    
map_Scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Which areas are grear opportunities
df_final[df_final['Pharmacy'] ==0].index
# Out:
# Index(['Alderwood, Long Branch', 'Bayview Village', 'Berczy Park',
#        'Birch Cliff, Cliffside West',
#        'Brockton, Parkdale Village, Exhibition Place',
#        'Business reply mail Processing Centre, South Central Letter Processing Plant Toronto',
#        'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport',
#        'Caledonia-Fairbanks', 'Canada Post Gateway Processing Centre',
#        'Cedarbrae', 'Central Bay Street', 'Christie', 'Church and Wellesley',
#        'Commerce Court, Victoria Hotel', 'Davisville',
#        'Del Ray, Mount Dennis, Keelsdale and Silverthorn',
#        'Dorset Park, Wexford Heights, Scarborough Town Centre',
#        'Dufferin, Dovercourt Village',
#        'East Toronto, Broadview North (Old East York)',
#        'First Canadian Place, Underground city', 'Garden District, Ryerson',
#        'Glencairn', 'Golden Mile, Clairlea, Oakridge',
#        'Harbourfront East, Union Station, Toronto Islands', 'Humber Summit',
#        'Humberlea, Emery', 'Humewood-Cedarvale',
#        'India Bazaar, The Beaches West',
#        'Kensington Market, Chinatown, Grange Park', 'Lawrence Park', 'Leaside',
#        'Little Portugal, Trinity', 'Malvern, Rouge',
#        'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West',
#        'Moore Park, Summerhill East',
#        'New Toronto, Mimico South, Humber Bay Shores',
#        'North Park, Maple Leaf Park, Upwood Park',
#        'North Toronto West, Lawrence Park',
#        'Northwest, West Humber - Clairville',
#        'Northwood Park, York University',
#        'Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East',
#        'Parkdale, Roncesvalles', 'Parkwoods',
#        'Queen's Park, Ontario Provincial Government',
#        'Regent Park, Harbourfront', 'Richmond, Adelaide, King', 'Rosedale',
#        'Roselawn', 'Rouge Hill, Port Union, Highland Creek',
#        'Runnymede, Swansea', 'Runnymede, The Junction North',
#        'Scarborough Village', 'St. James Town', 'St. James Town, Cabbagetown',
#        'Stn A PO Boxes', 'Studio District',
#        'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#        'The Annex, North Midtown, Yorkville', 'The Beaches',
#        'The Danforth West, Riverdale',
#        'Toronto Dominion Centre, Design Exchange',
#        'University of Toronto, Harbord', 'Upper Rouge', 'Victoria Village',
#        'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale',
#        'Westmount', 'Wexford, Maryvale', 'Willowdale, Newtonbrook',
#        'Willowdale, Willowdale East', 'Woburn', 'York Mills West',
#        'York Mills, Silver Hills'],
#       dtype='object')

# %%
## Main Pharmacy competitors

Scarborough_pharmacy['Venue'].value_counts()
# Out:
# Shoppers Drug Mart                    23
# Rexall                                 3
# Cliffwood I.D.A. Pharmacy              1
# Thorncrest Drug Store                  1
# Brimley Road Medical Center I.D.A.     1
# IDA Pharmacy                           1
# IDA High Park                          1
# Name: Venue, dtype: int64
